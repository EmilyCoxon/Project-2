# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %%
# Load and read weekly earnings data file, store into pandas dataframe, look at head
# 1. Weekly 
weekly_earnings_csv = pd.read_csv("Resources/weekly_earnings.csv")
weekly_earnings_df = pd.DataFrame(weekly_earnings_csv)
weekly_earnings_df.head(10)
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
# 5      Series Start
# 6        Series End
# 7           No. Obs
# 8         Series ID
# 9          May-2012
#
#   Earnings; Males; Full Time; Adult; Ordinary time earnings ;  Western Australia ;  \
# 0                                                  $
# 1                                Seasonally Adjusted
# 2                                              RATIO
# 3                                           Biannual
# 4                                                  2
# 5                                           May-2012
# 6                                           May-2022
# 7                                                 21
# 8                                         A85002053W
# 9                                            1659.80
#
#   Earnings; Males; Full Time; Adult; Total earnings ;  Western Australia ;  \
# ...

# %%
# Load and read Labour Force data file, store into pandas dataframe, look at head
#2. labour force
labour_force_csv = pd.read_csv("Resources/labour_force.csv")
labour_force_df = pd.DataFrame(labour_force_csv)
labour_force_df.head(10)
# Out:
#          Unnamed: 0 Employed total ;  Persons ; Employed total ;  Persons ;.1  \
# 0              Unit                         000                           000
# 1       Series Type                       Trend           Seasonally Adjusted
# 2         Data Type                       STOCK                         STOCK
# 3         Frequency                       Month                         Month
# 4  Collection Month                           1                             1
# 5      Series Start                    Feb-1978                      Feb-1978
# 6        Series End                    Oct-2022                      Oct-2022
# 7           No. Obs                         537                           537
# 8         Series ID                  A84423993J                    A84423321T
# 9          Feb-1978                       529.8                         524.1
#
#   Employed total ;  Persons ;.2 Employed total ;  > Males ;  \
# ...

# %%
# Load and read retail turnover data file, store into pandas dataframe, look at head
#3. retail turnover
retail_turnover_csv = pd.read_csv("Resources/retail_turnover.csv")
retail_turnover_df = pd.DataFrame(retail_turnover_csv)
retail_turnover_df.head(10)
# Out:
#          Unnamed: 0 Turnover ;  New South Wales ;  Total (Industry) ;  \
# 0              Unit                                        $ Millions
# 1       Series Type                                          Original
# 2         Data Type                                              FLOW
# 3         Frequency                                             Month
# 4  Collection Month                                                 1
# 5      Series Start                                          Apr-1982
# 6        Series End                                          Oct-2022
# 7           No. Obs                                               487
# 8         Series ID                                         A3348645F
# 9          Apr-1982                                            1250.2
#
#   Turnover ;  Victoria ;  Total (Industry) ;  \
# 0                                 $ Millions
# 1                                   Original
# 2                                       FLOW
# ...

# %%
# Clean weekly earnings dataset (units are $ dollars)
#Remove unneccesary rows (0-8, second column, 5th column, 8th column)
weekly_earnings_cleaned = weekly_earnings_df.drop(weekly_earnings_df.index[0:9])
weekly_earnings_cleaned.head()
# Out:
#    Unnamed: 0  \
# 9    May-2012
# 10   Nov-2012
# 11   May-2013
# 12   Nov-2013
# 13   May-2014
#
#    Earnings; Males; Full Time; Adult; Ordinary time earnings ;  Western Australia ;  \
# 9                                             1659.80
# 10                                            1746.70
# 11                                            1804.70
# 12                                            1754.10
# 13                                            1788.90
#
#    Earnings; Males; Full Time; Adult; Total earnings ;  Western Australia ;  \
# 9                                             1826.70
# 10                                            1888.50
# 11                                            1935.70
# 12                                            1869.00
# 13                                            1919.70
#
#    Earnings; Males; Total earnings ;  Western Australia ;  \
# 9                                             1556.10
# ...

# %%
#Remove 2nd, 5th, 8th columns
weekly_earnings_reduced = weekly_earnings_cleaned.drop(weekly_earnings_cleaned.columns[[1, 4, 7]], axis = 1)
weekly_earnings_reduced.head()
# Out:
#    Unnamed: 0  \
# 9    May-2012
# 10   Nov-2012
# 11   May-2013
# 12   Nov-2013
# 13   May-2014
#
#    Earnings; Males; Full Time; Adult; Total earnings ;  Western Australia ;  \
# 9                                             1826.70
# 10                                            1888.50
# 11                                            1935.70
# 12                                            1869.00
# 13                                            1919.70
#
#    Earnings; Males; Total earnings ;  Western Australia ;  \
# 9                                             1556.10
# 10                                            1614.90
# 11                                            1664.30
# 12                                            1619.20
# 13                                            1637.90
#
#    Earnings; Females; Full Time; Adult; Total earnings ;  Western Australia ;  \
# 9                                             1266.90
# ...

# %%
#check what the current headings are for columns
weekly_earnings_reduced.columns
# Out:
# Index(['Unnamed: 0',
#        'Earnings; Males; Full Time; Adult; Total earnings ;  Western Australia ;',
#        'Earnings; Males; Total earnings ;  Western Australia ;',
#        'Earnings; Females; Full Time; Adult; Total earnings ;  Western Australia ;',
#        'Earnings; Females; Total earnings ;  Western Australia ;',
#        'Earnings; Persons; Full Time; Adult; Total earnings ;  Western Australia ;',
#        'Earnings; Persons; Total earnings ;  Western Australia ;'],
#       dtype='object')

# %%
#Renaming Weekly Earnings Headings

weekly_earnings_reduced.columns = ['Date', 'Male_Earnings_Full_Time$', 'Male_Earnings_Total$', 
                                   'Female_Earnings_Full_Time$', 'Female_Earnings_Total$', 
                                   'People_Earnings_Full_Time$', 'People_Earnings_Total$']
weekly_earnings_reduced.head()
# Out:
#         Date Male_Earnings_Full_Time$ Male_Earnings_Total$  \
# 9   May-2012                  1826.70              1556.10
# 10  Nov-2012                  1888.50              1614.90
# 11  May-2013                  1935.70              1664.30
# 12  Nov-2013                  1869.00              1619.20
# 13  May-2014                  1919.70              1637.90
#
#    Female_Earnings_Full_Time$ Female_Earnings_Total$  \
# 9                     1266.90                 834.30
# 10                    1298.90                 847.30
# 11                    1350.50                 889.60
# 12                    1363.00                 917.10
# 13                    1359.60                 933.30
#
#    People_Earnings_Full_Time$ People_Earnings_Total$
# 9                     1635.20                1204.50
# 10                    1692.40                1244.00
# 11                    1740.50                1297.90
# 12                    1705.90                1296.30
# ...

# %%
labour_force_df.head(10)
# Out:
#          Unnamed: 0 Employed total ;  Persons ; Employed total ;  Persons ;.1  \
# 0              Unit                         000                           000
# 1       Series Type                       Trend           Seasonally Adjusted
# 2         Data Type                       STOCK                         STOCK
# 3         Frequency                       Month                         Month
# 4  Collection Month                           1                             1
# 5      Series Start                    Feb-1978                      Feb-1978
# 6        Series End                    Oct-2022                      Oct-2022
# 7           No. Obs                         537                           537
# 8         Series ID                  A84423993J                    A84423321T
# 9          Feb-1978                       529.8                         524.1
#
#   Employed total ;  Persons ;.2 Employed total ;  > Males ;  \
# ...

# %%
# remove unwanted rows (0-9)
labour_force_cleaned = labour_force_df.drop(labour_force_df.index[0:9])
labour_force_cleaned.head()
# Out:
#    Unnamed: 0 Employed total ;  Persons ; Employed total ;  Persons ;.1  \
# 9    Feb-1978                       529.8                         524.1
# 10   Mar-1978                       529.5                         529.4
# 11   Apr-1978                       529.1                         528.3
# 12   May-1978                       528.6                         528.9
# 13   Jun-1978                       528.0                         530.7
#
#    Employed total ;  Persons ;.2 Employed total ;  > Males ;  \
# 9                          522.9                       341.8
# 10                         530.7                       341.4
# 11                         531.7                       341.0
# 12                         532.5                       340.7
# 13                         532.2                       340.5
#
#    Employed total ;  > Males ;.1 Employed total ;  > Males ;.2  \
# 9                          342.5                         344.8
# ...

# %%
#keep certain columns(0, 2, 5, 8, 11, 14, 17) drop the rest
labour_force_reduced = labour_force_cleaned.iloc[:, [0,2,5,8,11,14,17]]
labour_force_reduced.head()
# Out:
#    Unnamed: 0 Employed total ;  Persons ;.1 Employed total ;  > Males ;.1  \
# 9    Feb-1978                         524.1                         342.5
# 10   Mar-1978                         529.4                         341.4
# 11   Apr-1978                         528.3                         340.6
# 12   May-1978                         528.9                         340.6
# 13   Jun-1978                         530.7                         342.6
#
#    Employed total ;  > Females ;.1 > Employed full-time ;  Persons ;.1  \
# 9                            181.6                               435.0
# 10                           188.0                               436.3
# 11                           187.7                               435.6
# 12                           188.2                               435.4
# 13                           188.1                               440.2
#
#    > Employed full-time ;  > Males ;.1 > Employed full-time ;  > Females ;.1
# ...

# %%
# rename the columns
labour_force_reduced.columns
# Out:
# Index(['Unnamed: 0', 'Employed total ;  Persons ;.1',
#        'Employed total ;  > Males ;.1', 'Employed total ;  > Females ;.1',
#        '> Employed full-time ;  Persons ;.1',
#        '> Employed full-time ;  > Males ;.1',
#        '> Employed full-time ;  > Females ;.1'],
#       dtype='object')

# %%
#rename columns
labour_force_reduced.columns = ['Date', 'Employed Total Persons (000)', 'Employed Total Males (000)', 'Employed Total Females (000)', 
                                'Employed Full Time Persons (000)', 'Employed Full Time Males (000)', 'Employed Full Time Females(000)']
labour_force_reduced.head()
# Out:
#         Date Employed Total Persons (000) Employed Total Males (000)  \
# 9   Feb-1978                        524.1                      342.5
# 10  Mar-1978                        529.4                      341.4
# 11  Apr-1978                        528.3                      340.6
# 12  May-1978                        528.9                      340.6
# 13  Jun-1978                        530.7                      342.6
#
#    Employed Total Females (000) Employed Full Time Persons (000)  \
# 9                         181.6                            435.0
# 10                        188.0                            436.3
# 11                        187.7                            435.6
# 12                        188.2                            435.4
# 13                        188.1                            440.2
#
#    Employed Full Time Males (000) Employed Full Time Females(000)
# 9                           324.5                           110.5
# ...

# %%
retail_turnover_df.head(10)
# Out:
#          Unnamed: 0 Turnover ;  New South Wales ;  Total (Industry) ;  \
# 0              Unit                                        $ Millions
# 1       Series Type                                          Original
# 2         Data Type                                              FLOW
# 3         Frequency                                             Month
# 4  Collection Month                                                 1
# 5      Series Start                                          Apr-1982
# 6        Series End                                          Oct-2022
# 7           No. Obs                                               487
# 8         Series ID                                         A3348645F
# 9          Apr-1982                                            1250.2
#
#   Turnover ;  Victoria ;  Total (Industry) ;  \
# 0                                 $ Millions
# 1                                   Original
# 2                                       FLOW
# ...

# %%
# remove unwanted rows (0-9)
retail_turnover_cleaned = retail_turnover_df.drop(retail_turnover_df.index[0:9])
retail_turnover_cleaned.head()
# Out:
#    Unnamed: 0 Turnover ;  New South Wales ;  Total (Industry) ;  \
# 9    Apr-1982                                            1250.2
# 10   May-1982                                            1300.0
# 11   Jun-1982                                            1234.2
# 12   Jul-1982                                            1265.0
# 13   Aug-1982                                            1217.6
#
#    Turnover ;  Victoria ;  Total (Industry) ;  \
# 9                                       916.2
# 10                                      931.2
# 11                                      887.0
# 12                                      921.3
# 13                                      883.2
#
#    Turnover ;  Queensland ;  Total (Industry) ;  \
# 9                                         486.3
# 10                                        492.8
# 11                                        494.1
# 12                                        515.6
# 13                                        501.4
#
# ...

# %%
#Filter data to keep two columns(0, 14)
retail_turnover_reduced = retail_turnover_cleaned.iloc[:, [0,14]]
retail_turnover_reduced.head()
# Out:
#    Unnamed: 0 Turnover ;  Western Australia ;  Total (Industry) ;.1
# 9    Apr-1982                                              313.0
# 10   May-1982                                              315.5
# 11   Jun-1982                                              321.2
# 12   Jul-1982                                              320.4
# 13   Aug-1982                                              318.5

# %%
#rename headers
retail_turnover_reduced.columns = ['Date', 'Retail Turnover WA ($ millions)']
retail_turnover_reduced.head()
# Out:
#         Date Retail Turnover WA ($ millions)
# 9   Apr-1982                           313.0
# 10  May-1982                           315.5
# 11  Jun-1982                           321.2
# 12  Jul-1982                           320.4
# 13  Aug-1982                           318.5

# %%
retail_turnover_reduced.dtypes
# Out:
# Date                               object
# Retail Turnover WA ($ millions)    object
# dtype: object

# %%
# unnecessary cell - keep for syntax notes only
# new_df = retail_turnover_reduced.loc[(retail_turnover_reduced["Date"] == "May-2021")|( 
#                                      retail_turnover_reduced["Date"] =="Nov-2021")|(retail_turnover_reduced["Date"] == "May-2021"),:]
# new_df.head()

# %%
df = pd.merge(weekly_earnings_reduced, labour_force_reduced, on='Date', how='inner')
df
# Out:
#         Date Male_Earnings_Full_Time$ Male_Earnings_Total$  \
# 0   May-2012                  1826.70              1556.10
# 1   Nov-2012                  1888.50              1614.90
# 2   May-2013                  1935.70              1664.30
# 3   Nov-2013                  1869.00              1619.20
# 4   May-2014                  1919.70              1637.90
# 5   Nov-2014                  1989.20              1686.60
# 6   May-2015                  1987.80              1682.70
# 7   Nov-2015                  1993.80              1633.10
# 8   May-2016                  1976.80              1635.70
# 9   Nov-2016                  1989.60              1637.70
# 10  May-2017                  1965.70              1637.20
# 11  Nov-2017                  1996.20              1654.80
# 12  May-2018                  1996.30              1642.90
# 13  Nov-2018                  2040.00              1640.70
# 14  May-2019                  2030.50              1643.70
# ...

# %%
df.count()
# Out:
# Date                                21
# Male_Earnings_Full_Time$            21
# Male_Earnings_Total$                21
# Female_Earnings_Full_Time$          21
# Female_Earnings_Total$              21
# People_Earnings_Full_Time$          21
# People_Earnings_Total$              21
# Employed Total Persons (000)        21
# Employed Total Males (000)          21
# Employed Total Females (000)        21
# Employed Full Time Persons (000)    21
# Employed Full Time Males (000)      21
# Employed Full Time Females(000)     21
# dtype: int64

# %%
final_df = pd.merge(df, retail_turnover_reduced, on='Date', how='inner')
final_df.head()
# Out:
#        Date Male_Earnings_Full_Time$ Male_Earnings_Total$  \
# 0  May-2012                  1826.70              1556.10
# 1  Nov-2012                  1888.50              1614.90
# 2  May-2013                  1935.70              1664.30
# 3  Nov-2013                  1869.00              1619.20
# 4  May-2014                  1919.70              1637.90
#
#   Female_Earnings_Full_Time$ Female_Earnings_Total$  \
# 0                    1266.90                 834.30
# 1                    1298.90                 847.30
# 2                    1350.50                 889.60
# 3                    1363.00                 917.10
# 4                    1359.60                 933.30
#
#   People_Earnings_Full_Time$ People_Earnings_Total$  \
# 0                    1635.20                1204.50
# 1                    1692.40                1244.00
# 2                    1740.50                1297.90
# 3                    1705.90                1296.30
# ...

# %% [markdown]
# ## Load
# ### Connect to local database

# %%
protocol = 'postgresql'
username = 'postgres'
password = 3720
host = 'localhost'
port = 5432
database_name = 'Final_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
insp = inspect(engine)

# %% [markdown]
#  ### Check for tables

# %%
insp.get_table_names()
# Out:
# ['weekly_earnings', 'Labour_Force', 'retail_turnover', 'Retail_Turnover']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database
# * NOTE: can also check using pgAdmin

# %%
# load weekly earnings dataset into database
weekly_earnings_reduced.to_sql(name='Weekly_Earnings', con=engine, if_exists='append', index=False)

# %%
# load labour force dataset into database
labour_force_reduced.to_sql(name='Labour_Force', con=engine, if_exists='append', index=False)

# %%
# load retail turnover dataset into database
retail_turnover_reduced.to_sql(name='Retail_Turnover', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
# Confirm data has been added by querying the weekly earnings table  
pd.read_sql_query('select * from Weekly_Earnings', con=engine).head()
# Out:
# Empty DataFrame
# Columns: [id, date, male_earnings_full_time$, male_earnings_total$, female_earnings_full_time$, female_earnings_total$, people_earnings_full_time$, people_earnings_total$]
# Index: []

# %%
# Confirm data has been added by querying the labour force table  
pd.read_sql_query('select * from Labour_Force', con=engine).head()
# Out:
# Empty DataFrame
# Columns: [id, date, employed_total_persons_000, employed_total_males_000, employed_total_females_000, employed_full_time_persons_000, employed_full_time_males_000, employed_full_time_females_000]
# Index: []

# %%
# Confirm data has been added by querying the Retail turnover table  
pd.read_sql_query('select * from Retail_Turnover', con=engine).head()
# Out:
# Empty DataFrame
# Columns: [id, date, retail_turnover_wa]
# Index: []

# %%
# join the tables
sql_join = r"""SELECT Weekly_Earnings.date, Weekly_Earnings.male_earnings_full_time$,

Weekly_Earnings.male_earnings_total$,Labour_Force.employed_total_males_000,Labour_Force.employed_full_time_males_000,
Weekly_Earnings.female_earnings_full_time$,Weekly_Earnings.female_earnings_total$, Labour_Force.employed_total_females_000,
Labour_Force.employed_full_time_females_000,
Weekly_Earnings.people_earnings_full_time$, Weekly_Earnings.people_earnings_total$,
Labour_Force.employed_total_persons_000, 
Labour_Force.employed_full_time_persons_000



FROM Weekly_Earnings
JOIN Labour_Force

ON Weekly_Earnings.date = Labour_Force.date"""
pd.read_sql_query(sql_join, con=engine).head()
# Out:
# Empty DataFrame
# Columns: [date, male_earnings_full_time$, male_earnings_total$, employed_total_males_000, employed_full_time_males_000, female_earnings_full_time$, female_earnings_total$, employed_total_females_000, employed_full_time_females_000, people_earnings_full_time$, people_earnings_total$, employed_total_persons_000, employed_full_time_persons_000]
# Index: []
